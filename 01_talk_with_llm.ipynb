# %%
print("ok")
# Out:
# ok

# %%
import os
from dotenv import load_dotenv,find_dotenv
_ = load_dotenv(find_dotenv())
openai_api_key = os.environ["OPENAI_API_KEY"]

# %% [markdown]
# ### Completion Model

# %%
from langchain_openai import OpenAI

llmModel = OpenAI()
llmModel.invoke("Tell me one fact about Gorantla Sai Krishna who works in Tredence.")
# Out:
# '\n\nGorantla Sai Krishna is a data analyst at Tredence with over 5 years of experience in the field of data analytics and has a strong expertise in predictive modeling and machine learning techniques.'

# %%
for chunk in llmModel.stream("Tell me one fact about kennedy family. I need detail response"):
    print(chunk,end="",flush=True)
# Out:
# The Kennedy family is an American political dynasty that has had a significant impact on U.S. history for over a century. One of their most notable contributions is their strong advocacy for civil rights and social justice.
#
# In the 1960s, President John F. Kennedy, along with his brother Attorney General Robert F. Kennedy, played a crucial role in advancing civil rights legislation and supporting the civil rights movement. They worked to desegregate schools and public places, protect voting rights, and promote equal opportunities for African Americans.
#
# Their efforts continued after John F. Kennedy's assassination when Robert F. Kennedy became a prominent leader in the movement. He worked closely with civil rights leaders such as Martin Luther King Jr. and was a key figure in the passage of the Civil Rights Act of 1964 and the Voting Rights Act of 1965.
#
# ...

# %% [markdown]
# ### ChatModel

# %%
from langchain_openai import ChatOpenAI

chatModel = ChatOpenAI(model = "gpt-3.5-turbo-0125")

# %%
messages = [
    ("system","You are an historian expert in the kennedy family."),
    ("human","Tell me one curious thing about JFK")
]
response = chatModel.invoke(messages)
print(response)
# Out:
# content='One curious thing about JFK is that he won a Pulitzer Prize for his book "Profiles in Courage" in 1957. It is unusual for a sitting U.S. President to win such a prestigious literary award. The book highlights acts of political courage by eight U.S. senators throughout American history.' response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 29, 'total_tokens': 89, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-3e991863-a094-4871-8879-161f5573f681-0' usage_metadata={'input_tokens': 29, 'output_tokens': 60, 'total_tokens': 89}

# %%
print(response.response_metadata)
# Out:
# {'token_usage': {'completion_tokens': 60, 'prompt_tokens': 29, 'total_tokens': 89, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}

# %% [markdown]
# ### Old LangChain

# %%
from langchain_core.messages import HumanMessage,SystemMessage
from langchain_core.prompts import ChatPromptTemplate

# %%
messages = [
    SystemMessage(content = "You are an historian expert in the kennedy family."),
    HumanMessage(content="How many children had Joseph P. Kennedy?")
]
response = chatModel.invoke(messages)
print(response)
# Out:
# content='Joseph P. Kennedy and his wife, Rose Kennedy, had nine children. Their children were Joseph Jr., John F. (JFK), Rosemary, Kathleen, Eunice, Patricia, Robert F. (Bobby), Jean, and Edward M. (Ted).' response_metadata={'token_usage': {'completion_tokens': 55, 'prompt_tokens': 31, 'total_tokens': 86, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-82aa11a1-2d20-4254-98ff-c87613b5680f-0' usage_metadata={'input_tokens': 31, 'output_tokens': 55, 'total_tokens': 86}

# %% [markdown]
# ### Alternative LLM (Open Source)

# %%
from langchain_groq import ChatGroq

llamaChatModel = ChatGroq(
    model = "llama-3.1-8b-instant"
)

llamaChatModel.invoke(messages)
# Out:
# AIMessage(content='Joseph P. Kennedy Sr., the patriarch of the Kennedy family, had nine children with his wife Rose Kennedy. \n\n1. Joseph P. Kennedy Jr. (1915-1944)\n2. John F. Kennedy (1917-1963)\n3. Rosemary Kennedy (1918-2005)\n4. Kathleen Kennedy (1920-1948)\n5. Eunice Kennedy (1921-2009)\n6. Patricia Kennedy (1924-2006)\n7. Robert F. Kennedy (1925-1968)\n8. Jean Kennedy (1928-2020)\n9. Ted Kennedy (1932-2009)', response_metadata={'token_usage': {'completion_tokens': 134, 'prompt_tokens': 55, 'total_tokens': 189, 'completion_time': 0.141263995, 'prompt_time': 0.003500568, 'queue_time': 0.056077882, 'total_time': 0.144764563}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_7b3cfae3af', 'finish_reason': 'stop', 'logprobs': None}, id='run-7ba6c9f0-2e95-4660-b526-29c685669b4b-0', usage_metadata={'input_tokens': 55, 'output_tokens': 134, 'total_tokens': 189})
